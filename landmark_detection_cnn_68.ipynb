# %%
from imutils import face_utils
import dlib
import cv2
import os
from scipy.spatial import distance
import numpy as np
from math import sqrt
import tensorflow as tf
from google.colab import drive

# %%
def get_landmarks_gt(path):
    landmarks_gt = list()
    f = open(path, "r")
    lines = f.readlines()
    for i, line in enumerate(lines):
        if i < 3 or i == len(lines)-1: continue
        x_gt, y_gt = line.split()
        landmarks_gt.append(np.array([float(x_gt), float(y_gt)]))
    return np.array(landmarks_gt)

# %%
def get_annotated_face(rects, landmarks_gt):
    rect_dict = dict()
    for i, face in enumerate(rects):
        c = 0
        x = face.rect.left()
        y = face.rect.top()
        w = face.rect.right() - x
        h = face.rect.bottom() - y
        for (x_gt, y_gt) in landmarks_gt:
            if (x <= x_gt <= x + w or x >= x_gt >= x + w) and (y <= y_gt <= y + h or y >= y_gt >= y + h):
                c += 1
        rect_dict[i] = c
    max_key = max(rect_dict, key=rect_dict.get)
    if rect_dict[max_key]/68 < 0.5:
      return rects[max_key].rect, True
    return rects[max_key].rect, False

# %%
def get_iod(landmarks):
    # Left eye center
    x_left = [p[0] for p in landmarks[36:42]]
    y_left = [p[1] for p in landmarks[36:42]]
    centroid_left = (int(sum(x_left) / len(landmarks[36:42])), int(sum(y_left) / len(landmarks[36:42])))
    # Right eye center
    x_right = [p[0] for p in landmarks[42:48]]
    y_right = [p[1] for p in landmarks[42:48]]
    centroid_right = (int(sum(x_right) / len(landmarks[42:48])), int(sum(y_right) / len(landmarks[42:48])))
    # IOD
    return distance.euclidean(centroid_left, centroid_right)

# %%
def convert_and_trim_bb(image, rect):
    startX = rect.left()
    startY = rect.top()
    endX = rect.right()
    endY = rect.bottom()
    startX = max(0, startX)
    startY = max(0, startY)
    endX = min(endX, image.shape[1])
    endY = min(endY, image.shape[0])
    w = endX - startX
    h = endY - startY
    return (startX, startY, w, h)

# %%
detector = dlib.cnn_face_detection_model_v1("./drive/MyDrive/mmod_human_face_detector.dat")
predictor = dlib.shape_predictor("./drive/MyDrive/shape_predictor_68_face_landmarks.dat")

# %%
input_dir = "/content/drive/MyDrive/SB_datasets/ibug/ibug_masked/"
output_dir = "./data/"

# %%
nrmse_global = list()
count_incorrect = 0
count_all = 0

for count, filename in enumerate(os.listdir(input_dir)):
    if not (filename.__contains__(".jpg") or filename.__contains__(".png")): continue
    error = False
    count_all += 1
    print("Processing: %s (%d)" % (filename, count_all))

    filename_s = os.path.splitext(filename)[0]
    landmarks_gt = get_landmarks_gt(input_dir+filename_s+".pts")

    image = cv2.imread(input_dir+filename)
    rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Draw all ground truth landmarks
    for (x, y) in landmarks_gt:
        cv2.circle(image, (int(x), int(y)), 2, (0, 0, 255), -1)

    # Get faces
    rects = detector(rgb, 0)
    for face in rects:
      x = face.rect.left()
      y = face.rect.top()
      w = face.rect.right() - x
      h = face.rect.bottom() - y
      cv2.rectangle(image, (x, y), (x + w, y + h), (255, 255, 0), 2)
    if len(rects) == 0:
      cv2.imwrite(output_dir+"errors/"+filename, image)
      count_incorrect += 1
      continue
    else:
      face, error = get_annotated_face(rects, landmarks_gt)

    # Make the prediction and transform it to numpy array
    landmarks = predictor(rgb, face)
    landmarks = face_utils.shape_to_np(landmarks)

    # IOD
    iod = get_iod(landmarks)

    distances = list()
    # Draw all predicted landmarks
    for i, (x, y) in enumerate(landmarks):
        cv2.circle(image, (x, y), 2, (0, 255, 0), -1)
        distance_normalized = (distance.euclidean(landmarks[i], landmarks_gt[i]) / iod)**2
        distances.append(distance_normalized)
    nrmse_local = sqrt(sum(distances)/len(distances))
    if not error:
      nrmse_global.append(nrmse_local)

    if error:
      count_incorrect += 1
      cv2.imwrite(output_dir+"errors/"+filename, image)
    else:
      cv2.imwrite(output_dir + filename, image)

print("NRMSE: %.5f, skipped %d of %d (%.3f)" % (np.mean(np.array(nrmse_global)), count_incorrect, count_all, count_incorrect/count_all))
# Out:
# Processing: image_004_1.jpg (1)
# Processing: image_003_1.jpg (2)
# Processing: image_005_1.jpg (3)
# Processing: image_008_1.jpg (4)
# Processing: image_010_1.jpg (5)
# Processing: image_011_1.jpg (6)
# Processing: image_013.jpg (7)
# Processing: image_012.jpg (8)
# Processing: image_014.jpg (9)
# Processing: image_014_01.jpg (10)
# Processing: image_014_02.jpg (11)
# Processing: image_015_1.jpg (12)
# Processing: image_017_1.jpg (13)
# Processing: image_016_1.jpg (14)
# Processing: image_019_1.jpg (15)
# Processing: image_021_1.jpg (16)
# Processing: image_020_1.jpg (17)
# Processing: image_022.jpg (18)
# Processing: image_023_1.jpg (19)
# Processing: image_024_1.jpg (20)
# Processing: image_026_1.jpg (21)
# Processing: image_025_1.jpg (22)
# Processing: image_029_1.jpg (23)
# Processing: image_033_1.jpg (24)
# Processing: image_034_1.jpg (25)
# Processing: image_035.jpg (26)
# Processing: image_041_1.jpg (27)
# Processing: image_040.jpg (28)
# Processing: image_042.jpg (29)
# Processing: image_043_1.jpg (30)
# Processing: image_045_1.jpg (31)
# Processing: image_047_1.jpg (32)
# Processing: image_046.jpg (33)
# Processing: image_049_1.jpg (34)
# Processing: image_050.jpg (35)
# Processing: image_050_01.jpg (36)
# Processing: image_051_1.jpg (37)
# Processing: image_052_1.jpg (38)
# Processing: image_053.jpg (39)
# Processing: image_054.jpg (40)
# Processing: image_055.jpg (41)
# Processing: image_059.jpg (42)
# Processing: image_060_1.jpg (43)
# Processing: image_057_1.jpg (44)
# Processing: image_058.jpg (45)
# Processing: image_062_1.jpg (46)
# Processing: image_061_1.jpg (47)
# Processing: image_064_1.jpg (48)
# Processing: image_063.jpg (49)
# Processing: image_065_1.jpg (50)
# Processing: image_067_1.jpg (51)
# Processing: image_068_1.jpg (52)
# Processing: image_066_1.jpg (53)
# Processing: image_069_1.jpg (54)
# Processing: image_070.jpg (55)
# Processing: image_071_1.jpg (56)
# Processing: image_072_1.jpg (57)
# Processing: image_073.jpg (58)
# Processing: image_075.jpg (59)
# Processing: image_076_1.jpg (60)
# Processing: image_078_1.jpg (61)
# Processing: image_077.jpg (62)
# Processing: image_080_1.jpg (63)
# Processing: image_080_2.jpg (64)
# Processing: image_081.jpg (65)
# Processing: image_083_2.jpg (66)
# Processing: image_084.jpg (67)
# Processing: image_087.jpg (68)
# Processing: image_086_1.jpg (69)
# Processing: image_087_01.jpg (70)
# Processing: image_088.jpg (71)
# Processing: image_089.jpg (72)
# Processing: image_089_02.jpg (73)
# Processing: image_089_01.jpg (74)
# Processing: image_09.jpg (75)
# Processing: image_090_1.jpg (76)
# Processing: image_092 _01.jpg (77)
# Processing: image_091.jpg (78)
# Processing: image_092.jpg (79)
# Processing: image_092_02.jpg (80)
# Processing: image_093.jpg (81)
# Processing: image_094.jpg (82)
# Processing: image_095.jpg (83)
# Processing: image_096.jpg (84)
# Processing: image_097_1.jpg (85)
# Processing: image_100.jpg (86)
# Processing: image_100_01.jpg (87)
# Processing: image_100_02.jpg (88)
# Processing: image_100_03.jpg (89)
# Processing: image_100_04.jpg (90)
# Processing: image_100_05.jpg (91)
# Processing: image_100_06.jpg (92)
# Processing: image_101.jpg (93)
# Processing: image_103.jpg (94)
# Processing: image_104.jpg (95)
# Processing: image_105.jpg (96)
# Processing: image_105_01.jpg (97)
# Processing: image_107.jpg (98)
# Processing: image_110.jpg (99)
# Processing: image_109.jpg (100)
# Processing: image_108.jpg (101)
# Processing: image_110_01.jpg (102)
# Processing: image_111.jpg (103)
# Processing: image_113.jpg (104)
# Processing: image_112.jpg (105)
# Processing: image_114.jpg (106)
# Processing: image_115.jpg (107)
# Processing: image_114_01.jpg (108)
# Processing: image_117.jpg (109)
# Processing: image_115_01.jpg (110)
# Processing: image_118.jpg (111)
# Processing: image_118_01.jpg (112)
# Processing: image_118_02.jpg (113)
# Processing: image_99.jpg (114)
# Processing: image_119.jpg (115)
# NRMSE: 0.26643, skipped 42 of 115 (0.365)

# %%
# !zip -r /content/file.zip ./data/
# Out:
#   adding: data/ (stored 0%)
#   adding: data/image_040.jpg (deflated 5%)
#   adding: data/image_115_01.jpg (deflated 3%)
#   adding: data/image_092.jpg (deflated 0%)
#   adding: data/image_010_1.jpg (deflated 5%)
#   adding: data/image_028.jpg (deflated 5%)
#   adding: data/image_118_02.jpg (deflated 2%)
#   adding: data/image_060_1.jpg (deflated 5%)
#   adding: data/image_045_1.jpg (deflated 3%)
#   adding: data/image_005_1.jpg (deflated 2%)
#   adding: data/image_105.jpg (deflated 2%)
#   adding: data/image_092 _01.jpg (deflated 0%)
#   adding: data/image_083_2.jpg (deflated 4%)
#   adding: data/image_100.jpg (deflated 4%)
#   adding: data/image_015_1.jpg (deflated 9%)
#   adding: data/image_004_1.jpg (deflated 2%)
#   adding: data/image_109.jpg (deflated 4%)
#   adding: data/image_055.jpg (deflated 3%)
#   adding: data/image_066_1.jpg (deflated 4%)
#   adding: data/image_074.jpg (deflated 0%)
#   adding: data/image_110_01.jpg (deflated 3%)
#   adding: data/image_108.jpg (deflated 4%)
#   adding: data/image_091.jpg (deflated 3%)
#   adding: data/.ipynb_checkpoints/ (stored 0%)
#   adding: data/image_026_1.jpg (deflated 3%)
#   adding: data/image_115.jpg (deflated 3%)
#   adding: data/image_072_1.jpg (deflated 3%)
#   adding: data/image_078_1.jpg (deflated 0%)
#   adding: data/image_106.jpg (deflated 2%)
#   adding: data/image_069_1.jpg (deflated 2%)
#   adding: data/image_011_1.jpg (deflated 4%)
#   adding: data/image_110.jpg (deflated 3%)
#   adding: data/image_100_01.jpg (deflated 4%)
#   adding: data/image_008_1.jpg (deflated 2%)
#   adding: data/errors/ (stored 0%)
#   adding: data/errors/image_100_03.jpg (deflated 4%)
#   adding: data/errors/image_081.jpg (deflated 0%)
#   adding: data/errors/image_087.jpg (deflated 2%)
#   adding: data/errors/image_117.jpg (deflated 1%)
#   adding: data/errors/image_056.jpg (deflated 0%)
#   adding: data/errors/image_100_02.jpg (deflated 4%)
#   adding: data/errors/image_087_01.jpg (deflated 2%)
#   adding: data/errors/image_050.jpg (deflated 1%)
#   adding: data/image_059.jpg (deflated 6%)
#   adding: data/image_047_1.jpg (deflated 2%)
#   adding: data/image_030.jpg (deflated 2%)
#   adding: data/image_101.jpg (deflated 8%)
#   adding: data/image_016_1.jpg (deflated 2%)
#   adding: data/image_067_1.jpg (deflated 4%)
#   adding: data/image_086_1.jpg (deflated 3%)
#   adding: data/image_031.jpg (deflated 8%)
#   adding: data/image_024_1.jpg (deflated 4%)
#   adding: data/image_99.jpg (deflated 1%)
#   adding: data/image_077.jpg (deflated 8%)
#   adding: data/image_102.jpg (deflated 7%)
#   adding: data/image_034_1.jpg (deflated 8%)
#   adding: data/image_019_1.jpg (deflated 2%)
#   adding: data/image_014.jpg (deflated 0%)
#   adding: data/image_063.jpg (deflated 4%)
#   adding: data/image_118_01.jpg (deflated 2%)
#   adding: data/image_103.jpg (deflated 2%)
#   adding: data/image_038.jpg (deflated 3%)
#   adding: data/image_057_1.jpg (deflated 6%)
#   adding: data/image_073.jpg (deflated 1%)
#   adding: data/image_070.jpg (deflated 0%)
#   adding: data/image_058.jpg (deflated 3%)
#   adding: data/image_014_01.jpg (deflated 0%)
#   adding: data/image_100_04.jpg (deflated 4%)
#   adding: data/image_089.jpg (deflated 3%)
#   adding: data/image_089_01.jpg (deflated 3%)
#   adding: data/image_118.jpg (deflated 2%)
#   adding: data/image_113.jpg (deflated 3%)
#   adding: data/image_085.jpg (deflated 0%)
#   adding: data/image_097_1.jpg (deflated 3%)
#   adding: data/image_09.jpg (deflated 2%)
#   adding: data/image_013.jpg (deflated 11%)
#   adding: data/image_043_1.jpg (deflated 3%)
#   adding: data/image_020_1.jpg (deflated 3%)
#   adding: data/image_084.jpg (deflated 2%)
#   adding: data/image_014_02.jpg (deflated 0%)
#   adding: data/image_094.jpg (deflated 2%)
#   adding: data/image_033_1.jpg (deflated 0%)
#   adding: data/image_006.jpg (deflated 1%)
#   adding: data/image_022.jpg (deflated 3%)
#   adding: data/image_090_1.jpg (deflated 2%)
#   adding: data/image_100_06.jpg (deflated 4%)
#   adding: data/image_092_02.jpg (deflated 0%)
#   adding: data/image_035.jpg (deflated 1%)
#   adding: data/image_111.jpg (deflated 0%)
#   adding: data/image_023_1.jpg (deflated 2%)
#   adding: data/image_105_01.jpg (deflated 2%)
#   adding: data/image_080_2.jpg (deflated 2%)
#   adding: data/image_114_01.jpg (deflated 4%)
#   adding: data/image_044.jpg (deflated 2%)
#   adding: data/image_089_02.jpg (deflated 3%)
#   adding: data/image_088.jpg (deflated 3%)
#   adding: data/image_061_1.jpg (deflated 1%)
#   adding: data/image_054.jpg (deflated 13%)
#   adding: data/image_093.jpg (deflated 4%)
#   adding: data/image_018.jpg (deflated 5%)
#   adding: data/image_071_1.jpg (deflated 11%)
#   adding: data/image_003_1.jpg (deflated 5%)
#   adding: data/image_021_1.jpg (deflated 2%)
#   adding: data/image_041_1.jpg (deflated 3%)
#   adding: data/image_053.jpg (deflated 3%)
#   adding: data/image_012.jpg (deflated 5%)
#   adding: data/image_112.jpg (deflated 5%)
#   adding: data/image_065_1.jpg (deflated 3%)
#   adding: data/image_048.jpg (deflated 7%)
#   adding: data/image_046.jpg (deflated 5%)
#   adding: data/image_064_1.jpg (deflated 4%)
#   adding: data/image_107.jpg (deflated 2%)
#   adding: data/image_116.jpg (deflated 1%)
#   adding: data/image_100_05.jpg (deflated 4%)
#   adding: data/image_051_1.jpg (deflated 2%)
#   adding: data/image_096.jpg (deflated 1%)
#   adding: data/image_068_1.jpg (deflated 1%)
#   adding: data/image_095.jpg (deflated 2%)
#   adding: data/image_049_1.jpg (deflated 3%)
#   adding: data/image_062_1.jpg (deflated 0%)
#   adding: data/image_037_1.jpg (deflated 4%)
#   adding: data/image_050_01.jpg (deflated 1%)
#   adding: data/image_027.jpg (deflated 0%)
#   adding: data/image_025_1.jpg (deflated 5%)
#   adding: data/image_114.jpg (deflated 4%)
#   adding: data/image_052_1.jpg (deflated 2%)
#   adding: data/image_082.jpg (deflated 1%)
#   adding: data/image_075.jpg (deflated 4%)
#   adding: data/image_119.jpg (deflated 1%)
#   adding: data/image_076_1.jpg (deflated 3%)
#   adding: data/image_029_1.jpg (deflated 4%)
#   adding: data/image_039.jpg (deflated 1%)
#   adding: data/image_007.jpg (deflated 1%)
#   adding: data/image_104.jpg (deflated 1%)
#   adding: data/image_017_1.jpg (deflated 5%)
#   adding: data/image_042.jpg (deflated 3%)
#   adding: data/image_080_1.jpg (deflated 2%)
#   adding: data/image_036.jpg (deflated 5%)

# %%
rm -rf ./data/*

# %%
mkdir ./data/errors

# %%
rm -rf file.zip
